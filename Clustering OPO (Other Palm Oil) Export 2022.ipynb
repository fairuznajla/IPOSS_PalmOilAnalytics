# %% [markdown]
# <a href="https://colab.research.google.com/github/fairuznajla/IPOSS_PalmOilAnalytics/blob/main/Clustering%20OPO%20(Other%20Palm%20Oil)%20Export%202022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import Dataset

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as tick
import seaborn as sns
mpl.style.use(["seaborn"])
# Out:
# <ipython-input-3-83529265c05f>:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   mpl.style.use(["seaborn"])

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/ekspor_opo.csv')
data
# Out:
#            negara_tujuan  volume_ekspor  nilai_ekspor  tahun    deskripsi_hs
# 0                Albania            811          1099   2022  Other Palm Oil
# 1                Algeria         117858        131756   2022  Other Palm Oil
# 2                 Angola         146266        188007   2022  Other Palm Oil
# 3    Antigua And Barbuda            176           266   2022  Other Palm Oil
# 4              Argentina            395           571   2022  Other Palm Oil
# ..                   ...            ...           ...    ...             ...
# 129        United States        1536734       1757429   2022  Other Palm Oil
# 130              Vanuatu            963          1414   2022  Other Palm Oil
# 131            Venezuela             70           111   2022  Other Palm Oil
# 132              Vietnam         697748        739729   2022  Other Palm Oil
# 133                Yemen          49637         52414   2022  Other Palm Oil
#
# [134 rows x 5 columns]

# %% [markdown]
# # Data Understanding : Exploratory Data Analysis (EDA)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   negara_tujuan  134 non-null    object
#  1   volume_ekspor  134 non-null    int64
#  2   nilai_ekspor   134 non-null    int64
#  3   tahun          134 non-null    int64
#  4   deskripsi_hs   134 non-null    object
# dtypes: int64(3), object(2)
# memory usage: 5.4+ KB

# %%
# Dataset Shape
data.shape
# Out:
# (134, 5)

# %% [markdown]
# ## Descriptive Statistics

# %%
# Numerik
data.describe().T
# Out:
#                count           mean            std     min      25%     50%  \
# volume_ekspor  134.0  160703.410448  471765.514022    17.0   600.25  6099.0
# nilai_ekspor   134.0  181607.686567  516296.254635    18.0   751.50  7159.5
# tahun          134.0    2022.000000       0.000000  2022.0  2022.00  2022.0
#
#                      75%        max
# volume_ekspor   94630.25  3477843.0
# nilai_ekspor   106004.75  3559229.0
# tahun            2022.00     2022.0

# %%
# !pip install dython
from dython.nominal import associations
# Out:
# Requirement already satisfied: dython in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from dython) (1.23.5)
# Requirement already satisfied: pandas>=1.4.2 in /usr/local/lib/python3.10/dist-packages (from dython) (1.5.3)
# Requirement already satisfied: seaborn>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from dython) (0.13.1)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from dython) (1.11.4)
# Requirement already satisfied: matplotlib>=3.5.3 in /usr/local/lib/python3.10/dist-packages (from dython) (3.7.1)
# Requirement already satisfied: scikit-learn>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from dython) (1.2.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in /usr/local/lib/python3.10/dist-packages (from dython) (0.3.7)
# Requirement already satisfied: psutil>=5.9.1 in /usr/local/lib/python3.10/dist-packages (from dython) (5.9.5)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.5.3->dython) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4.2->dython) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->dython) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.24.2->dython) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.5.3->dython) (1.16.0)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ##  Data Preprocessing and Data Cleaning

# %%
# Menghapus kolom yang tidak dibutuhkan

data = data.drop(['nilai_ekspor', 'tahun', 'deskripsi_hs'], axis=1)

# %%
data
# Out:
#            negara_tujuan  volume_ekspor
# 0                Albania            811
# 1                Algeria         117858
# 2                 Angola         146266
# 3    Antigua And Barbuda            176
# 4              Argentina            395
# ..                   ...            ...
# 129        United States        1536734
# 130              Vanuatu            963
# 131            Venezuela             70
# 132              Vietnam         697748
# 133                Yemen          49637
#
# [134 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Pisahkan tipe datanya menjadi numerical dan categorical
num_cols = data.select_dtypes(include=['float', 'int']).columns
cat_cols = data.select_dtypes(include=['object']).columns

print(f"Numerical Columns\t({len(num_cols)})\t: {list(num_cols)}")
print(f"Categorical Columns\t({len(cat_cols)})\t: {list(cat_cols)}")
# Out:
# Numerical Columns	(1)	: ['volume_ekspor']
# Categorical Columns	(1)	: ['negara_tujuan']

# %%
data_categ = data[cat_cols]
for i in cat_cols:
    Lenc = LabelEncoder()
    data_categ[i] = Lenc.fit_transform(data_categ[i])
    data[i] = data_categ[i]
# Out:
# <ipython-input-11-227d484c7752>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_categ[i] = Lenc.fit_transform(data_categ[i])

# %%
data
# Out:
#      negara_tujuan  volume_ekspor
# 0                0            811
# 1                1         117858
# 2                2         146266
# 3                3            176
# 4                4            395
# ..             ...            ...
# 129            129        1536734
# 130            130            963
# 131            131             70
# 132            132         697748
# 133            133          49637
#
# [134 rows x 2 columns]

# %% [markdown]
# # K-Means Clustering Modelling

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score

# %%
# Menentukan variabel untuk clustering
X = data[['negara_tujuan', 'volume_ekspor']]

# %%
# Standardisasi variabel numerik
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), ['negara_tujuan'])
    ],
    remainder='passthrough'
)

# %%
# Membangun pipeline dengan KMeans
pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('kmeans', KMeans(random_state=26))
])

# %%
# Menghitung inersia untuk berbagai jumlah cluster
inertia_values = []
for k in range(1, 11):
    pipeline.set_params(kmeans__n_clusters=k)
    pipeline.fit(X)
    inertia_values.append(pipeline.named_steps['kmeans'].inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Menampilkan plot elbow
plt.figure(figsize=(10, 6))
sns.lineplot(x=range(1, 11), y=inertia_values, marker='o')
plt.title('Elbow Plot for Optimal Number of Clusters')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.show()

# %%
# Pilih jumlah cluster berdasarkan elbow di plot
optimal_clusters = 3

# %%
# Melakukan clustering dengan jumlah cluster optimal
pipeline.set_params(kmeans__n_clusters=optimal_clusters)
pipeline.fit(X)
data['cluster_kmeans'] = pipeline.predict(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Menampilkan hasil clustering
print(data)
# Out:
#      negara_tujuan  volume_ekspor  cluster_kmeans
# 0                0            811               0
# 1                1         117858               0
# 2                2         146266               0
# 3                3            176               0
# 4                4            395               0
# ..             ...            ...             ...
# 129            129        1536734               2
# 130            130            963               0
# 131            131             70               0
# 132            132         697748               2
# 133            133          49637               0
#
# [134 rows x 3 columns]

# %% [markdown]
# K-Means Clustering
# 0 : rendah
# 1 : tinggi
# 2 : sedang

# %%
# Visualisasi clusters menggunakan scatter plot
sns.scatterplot(x='volume_ekspor', y='negara_tujuan', hue='cluster_kmeans', data=data, palette='viridis')
plt.title('Scatter Plot of Clusters')
plt.show()

# %% [markdown]
# ## Model Evaluation

# %%
# Semakin tinggi nilai silhoutte maka nilai clusternya makin baik
silhouette_scores = []

for n_cluster in range(2,10):
    silhouette_scores.append(
        silhouette_score(data, KMeans(n_clusters = n_cluster).fit_predict(data)))

plt.bar(range(2,10), silhouette_scores)
plt.xlabel('Number of clusters', fontsize = 10)
plt.ylabel('Silhouette Score', fontsize = 10)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# # Hierarchical/Agglomerative Clustering Modelling

# %%
# Import library
import matplotlib.pyplot as plt
import seaborn as sns #melakukan plot variable dalam bentuk diagram batang
from sklearn.cluster import AgglomerativeClustering #untuk melakukan hierarchiral clustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.metrics import silhouette_score #untuk mengukur kualitas cluster
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.preprocessing import StandardScaler #untuk menyeragamkan nilai data
from sklearn.decomposition import PCA #untuk reduksi fitur data sehingga bisa divisualisasi 2 dimensi
from sklearn.metrics.pairwise import cosine_similarity

# %%
# Plot dendogram, menghubungkan data-data yang jaraknya dekat dalam satu cluster
plt.figure(figsize=(10,5))
plt.title('Dendrogram Hierarchical Clustering')
plt.xlabel('negara_tujuan')
plt.ylabel('volume_ekspor')
dendrogram(linkage(data,method="ward"), leaf_rotation=90, p=5, color_threshold=20, leaf_font_size=10)
plt.show()

# %%
# Agglomerative clustering dengan jumlah cluster = 3
agglo = AgglomerativeClustering(n_clusters=3)
agglo.fit(data)
labels = agglo.labels_
hasil_agglo=pd.concat([data, pd.DataFrame({'cluster_hierarki':labels})], axis=1)
hasil_agglo
# Out:
#      negara_tujuan  volume_ekspor  cluster_kmeans  cluster_hierarki
# 0                0            811               0                 2
# 1                1         117858               0                 2
# 2                2         146266               0                 2
# 3                3            176               0                 2
# 4                4            395               0                 2
# ..             ...            ...             ...               ...
# 129            129        1536734               2                 0
# 130            130            963               0                 2
# 131            131             70               0                 2
# 132            132         697748               2                 0
# 133            133          49637               0                 2
#
# [134 rows x 4 columns]

# %%
# Assuming df is your DataFrame
hasil_agglo.to_csv('data_cluster.csv', index=False)

# Download the CSV file
from google.colab import files
files.download('data_cluster.csv')

# %% [markdown]
# ## Model Evaluation

# %%
# Mencari jumlah cluster terbaik dengan silhouette scores, disini untuk cluster 2 hingga 10. Semakin tinggi nilai silhoutte maka nilai clusternya makin baik
silhouette_scores = []

for n_cluster in range(2,10):
    silhouette_scores.append(
        silhouette_score(data, AgglomerativeClustering(n_clusters = n_cluster).fit_predict(data)))

plt.bar(range(2,10), silhouette_scores)
plt.xlabel('Number of clusters', fontsize = 10)
plt.ylabel('Silhouette Score', fontsize = 10)
plt.show()
